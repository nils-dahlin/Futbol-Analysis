# %% [markdown]
# # Scraping Data for Arsenal (Football Team)

# %%
import requests
import random
import pandas as pd
import warnings
# Hide FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# URL for Leeds 
team_url = "https://fbref.com/en/squads/18bb7c10/2025-2026/all_comps/Arsenal-Stats-All-Competitions"

# Sending HTTP GET-request to webpage
# user agents
userAgents = [
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 15_7_2) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/26.0 Safari/605.1.15',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 15.7; rv:146.0) Gecko/20100101 Firefox/146.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 15_7_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 15_7_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Vivaldi/7.7.3851.58',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 15_7_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.3650.80'
]
response = requests.get(team_url, headers={'User-Agent': random.choice(userAgents)})

# check for success response (statuscode 200)
if response.status_code == 200:
    print("Successfully retrieved page")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Failed to retrieve page. Status code: 403

# %%
from bs4 import BeautifulSoup
# Create a BeautifulSoup-objekt for navigating in HTML
soup = BeautifulSoup(data.text, "html.parser")

# Print first 500 characters to get an overview
print(soup.prettify()[:500])
